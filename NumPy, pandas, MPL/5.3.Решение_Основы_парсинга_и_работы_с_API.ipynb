# %% [markdown]
# # Задание 1.
# Обязательная часть
# Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в заголовках которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = [‘python’, ‘парсинг’]
#
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup

# %%
keywords = ['python', 'парсинг']
URL = 'https://habr.com/ru/all/'

# %%
pages = 3

result_list = []

for i in range(pages + 1):
    if i == 0:
        URL = 'https://habr.com/ru/all/'
    else:
        URL = 'https://habr.com/ru/all/' + 'page' + str(i) +'/' 
    req = requests.get(URL)
    time.sleep(0.3)
    soup = BeautifulSoup(req.text)
    news_blocks = soup.find_all('article', class_='tm-articles-list__item')
    articles_date = list(map(lambda x: x.find('span', class_='tm-article-snippet__datetime-published').find('time').get('title'), news_blocks))
    articles_title = list(map(lambda x: x.find('h2', class_='tm-article-snippet__title').find('span').get_text(), news_blocks))
    #articles_text = list(map(lambda x: x.find('div', class_='article-formatted-body').get_text(), news_blocks))
    articles_text = list(map(lambda x: x.find('div', class_='article-formatted-body'), news_blocks))
    articles_link = list(map(lambda x: x.find('a', class_='tm-article-snippet__title-link').get('href'), news_blocks))
    #result_list = result_list + list(zip(articles_date, articles_title, articles_text, articles_link))
    result_list = result_list + list(zip(articles_date, articles_title,  articles_link))


result_list
# Out:
# [('2022-03-20, 18:22',
#   'Китайские исследователи плотно изучают образцы лунного грунта, привезённые «Чанъэ-5»',
#   '/ru/post/656551/'),
#  ('2022-03-20, 17:58',
#   'Как обновить ClamAV через TOR для Windows',
#   '/ru/post/656549/'),
#  ('2022-03-20, 17:22',
#   'Разбираем алгоритмы компьютерной графики. Часть 3 – анимация «Пламя»',
#   '/ru/post/656541/'),
#  ('2022-03-20, 14:59',
#   'Можно ли определить поведение, просканировав мозг? Исследование показывает, что пока нет',
#   '/ru/post/656531/'),
#  ('2022-03-20, 14:55', 'Angular без CLI Туториал', '/ru/post/656529/'),
#  ('2022-03-20, 14:21', 'Генерируем Rust обёртку для FMOD', '/ru/post/656525/'),
#  ('2022-03-20, 13:36',
#   "«Живые» кликабельные обои на Python'е?",
#   '/ru/post/656521/'),
#  ('2022-03-20, 13:36',
#   'Немного полезностей недавно отбывшим от искушенного кочевника',
#   '/ru/post/656519/'),
#  ('2022-03-20, 13:00',
#   'Оптическое распознавание символов с помощью Rust и WebAssembly',
# ...

# %%
news = pd.DataFrame()

for e in keywords:
    for el in result_list:
        if e in  el[1].lower() or e in el[2].lower():
            row = {'date': el[0], 'title': el[1], 'link': 'https://habr.com' + el[2]}
            news = pd.concat([news, pd.DataFrame([row])])

# %%
news
# Out:
#                 date                                              title  \
# 0  2022-03-20, 13:36             «Живые» кликабельные обои на Python'е?
# 0  2022-03-20, 12:07         Создание APP для самотестирования (Python)
# 0  2022-03-20, 13:36             «Живые» кликабельные обои на Python'е?
# 0  2022-03-20, 12:07         Создание APP для самотестирования (Python)
# 0  2022-03-19, 19:36  Уроки компьютерного зрения на Python + OpenCV ...
#
#                                link
# 0  https://habr.com/ru/post/656521/
# 0  https://habr.com/ru/post/656517/
# 0  https://habr.com/ru/post/656521/
# 0  https://habr.com/ru/post/656517/
# 0  https://habr.com/ru/post/656489/

# %% [markdown]
# # Задание 2.
# Обязательная часть
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <дата утечки> - <источник утечки> - <описание утечки>
#
# Подсказка: сервис работает при помощи “скрытого” API. Внимательно изучите post-запросы.
#
# Дополнительная часть (необязательная)
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
#
# GROUP = 'netology’
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>
#
# ПРИМЕЧАНИЕ

# %%
EMAIL = ['xxx@x.ru', 'yyy@y.com']

url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

# %%
res = requests.post(url, headers = {'Vaar-Version': '0', 
                                    'Vaar-Header-App-Product-Name': 'hackcheck-web-avast',
                                    'Vaar-Header-App-Build-Version': '1.0.0'
                                   }, 
                    json = {'emailAddresses': EMAIL})
res.text
# Out:
# '{"breaches":{"17110":{"breachId":17110,"site":"azcentral.com","recordsCount":705538,"description":"At an unconfirmed date, online Arizona newspaper \\"AZ Central\\" was allegedly breached. The stolen data contains passwords and email addresses. This breach is being publicly shared on the internet.","publishDate":"2020-01-03T00:00:00Z","statistics":{"usernames":0,"passwords":702971,"emails":705538}},"37177":{"breachId":37177,"site":"forums.vkmonline.com","recordsCount":825654,"description":"At an unconfirmed date, the Russian-language music forum VKM was allegedly breached. The stolen data contains passwords, IPs, email addresses, usernames and additional personal information. This breach is being privately shared on the internet.","publishDate":"2021-02-11T00:00:00Z","statistics":{"usernames":825566,"passwords":825654,"emails":824936}},"41":{"breachId":41,"site":"dropbox.com","recordsCount":68591031,"description":"Cloud storage company Dropbox suffered a major data breach in 2012. C
# ...

# %%
res.json()
# Out:
# {'breaches': {'12': {'breachId': 12,
#    'description': "Popular Russian social networking platform VKontakte was breached in late 2012. Over 100 million clear-text passwords were compromised in the breach. Breached credential sets included victims' e-mail addresses, passwords, dates of birth, phone numbers and location details. The credential set was advertised on a dark web marketplace as of June 2016 for a price of one bitcoin. ",
#    'publishDate': '2016-10-29T00:00:00Z',
#    'recordsCount': 110121799,
#    'site': 'vk.com',
#    'statistics': {'emails': 104247327,
#     'passwords': 107425364,
#     'usernames': 0}},
#   '13094': {'breachId': 13094,
# ...

# %%
df = pd.DataFrame(res.json()['breaches'])
df
# Out:
#                                                           17110  \
# breachId                                                  17110
# site                                              azcentral.com
# recordsCount                                             705538
# description   At an unconfirmed date, online Arizona newspap...
# publishDate                                2020-01-03T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 702971, 'emails'...
#
#                                                           37177  \
# breachId                                                  37177
# site                                       forums.vkmonline.com
# recordsCount                                             825654
# description   At an unconfirmed date, the Russian-language m...
# publishDate                                2021-02-11T00:00:00Z
# statistics    {'usernames': 825566, 'passwords': 825654, 'em...
#
# ...

# %%
df_new = df.T
df_new[['publishDate','site','description']]
# Out:
#                 publishDate                  site  \
# 17110  2020-01-03T00:00:00Z         azcentral.com
# 37177  2021-02-11T00:00:00Z  forums.vkmonline.com
# 41     2016-10-24T00:00:00Z           dropbox.com
# 17009  2019-10-17T00:00:00Z             zynga.com
# 12     2016-10-29T00:00:00Z                vk.com
# 3      2016-10-21T00:00:00Z             adobe.com
# 13662  2018-02-18T00:00:00Z            netlog.com
# 3520   2017-03-15T00:00:00Z        globalreach.eu
# 3164   2017-02-14T00:00:00Z         cfire.mail.ru
# 2961   2017-01-31T00:00:00Z      cdprojektred.com
# 15     2016-10-23T00:00:00Z             imesh.com
# 3669   2017-03-24T00:00:00Z             youku.com
# 17670  2020-05-28T00:00:00Z           wishbone.io
# 13094  2017-11-04T00:00:00Z        myheritage.com
# 16768  2019-06-13T00:00:00Z             canva.com
# 3176   2017-02-14T00:00:00Z        parapa.mail.ru
# 2      2016-10-21T00:00:00Z          linkedin.com
# 3587   2017-03-01T00:00:00Z          rayli.com.cn
#
# ...

# %% [markdown]
# # Комментарии преподавателя
#
# Алексей, добрый день!
#
# Спасибо, работа отличная, по обоим заданиям получен верный результат.
#
# Замечательно, что разобрались с этой непростой темой :)
#
# Я бы только рекомендовал в таких задачах декомпозировать код на функции, чтобы в дальнейшем его было легче поддерживать и переиспользовать.
#
# Зачет!
